# %% [markdown]
# ## Hypothesis 3: People with a higher personal income per week tend to live in areas near/along the coast.

# %%
#2011 Data
import pandas as pd
Income_2011A = pd.read_csv("2011Census_B17A_WA_POA_short.csv") #index_col = 0)

# %%
Income_2011B = pd.read_csv("2011Census_B17B_WA_POA_short.csv") #index_col = 0)

# %%
Income_2011 = pd.merge(Income_2011A, Income_2011B, left_on="region_id", right_on="region_id")

# %%
Income_2011.head()
# Out:
#   region_id  M_Neg_Nil_income_15_19_yrs  M_Neg_Nil_income_20_24_yrs  \
# 0   POA6000                          51                          66
# 1   POA6003                          16                          23
# 2   POA6004                          62                          64
# 3   POA6005                          18                          25
# 4   POA6006                          54                          30
#
#    M_Neg_Nil_income_25_34_yrs  M_Neg_Nil_income_35_44_yrs  \
# 0                          82                          27
# 1                          18                          15
# 2                          58                          22
# 3                          39                          11
# 4                          25                          19
#
#    M_Neg_Nil_income_45_54_yrs  M_Neg_Nil_income_55_64_yrs  \
# 0                          19                          15
# 1                           5                           7
# ...

# %%
Income_2011.columns.get_loc('P_Neg_Nil_income_Tot')
# Out:
# 270

# %%
Income_2011.columns.get_loc('P_2000_more_Tot')
# Out:
# 370

# %%
Income_2011_6010 = Income_2011.iloc[8, 270:371:10]
Income_2011_6010
# Out:
# P_Neg_Nil_income_Tot    1261
# P_1_199_Tot              995
# P_200_299_Tot            705
# P_300_399_Tot            855
# P_400_599_Tot           1194
# P_600_799_Tot            837
# P_800_999_Tot            798
# P_1000_1249_Tot          878
# P_1250_1499_Tot          697
# P_1500_1999_Tot         1017
# P_2000_more_Tot         2525
# Name: 8, dtype: object

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(20, 10))
Income_2011_6010.plot(kind='bar', color = "green")

plt.xlabel("Personal Income Per Week")
plt.ylabel("Frequency")
plt.title("2011 Distribution of Personal Incomes Per Week in Claremont")
plt.show()

# %%
Income_2011_6015 = Income_2011.iloc[12, 270:371:10]
Income_2011_6015
# Out:
# P_Neg_Nil_income_Tot     596
# P_1_199_Tot              427
# P_200_299_Tot            274
# P_300_399_Tot            254
# P_400_599_Tot            413
# P_600_799_Tot            330
# P_800_999_Tot            305
# P_1000_1249_Tot          345
# P_1250_1499_Tot          263
# P_1500_1999_Tot          376
# P_2000_more_Tot         1232
# Name: 12, dtype: object

# %%
plt.figure(figsize=(20, 10))
Income_2011_6015.plot(kind='bar', color = "limegreen")

plt.xlabel("Personal Income Per Week")
plt.ylabel("Frequency")
plt.title("2011 Distribution of Personal Incomes Per Week in City Beach")
plt.show()

# %%
Income_2011_6056 = Income_2011.iloc[46, 270:371:10]
Income_2011_6056
# Out:
# P_Neg_Nil_income_Tot     747
# P_1_199_Tot              656
# P_200_299_Tot            853
# P_300_399_Tot            828
# P_400_599_Tot           1061
# P_600_799_Tot            979
# P_800_999_Tot            919
# P_1000_1249_Tot          953
# P_1250_1499_Tot          639
# P_1500_1999_Tot          665
# P_2000_more_Tot          452
# Name: 46, dtype: object

# %%
plt.figure(figsize=(20, 10))
Income_2011_6056.plot(kind='bar', color = "lightgreen")

plt.xlabel("Personal Income Per Week")
plt.ylabel("Frequency")
plt.title("2011 Distribution of Personal Incomes Per Week in Midland")
plt.show()

# %%
Income_2016A = pd.read_csv("2016Census_G17A_WA_POA.csv") #index_col = 0)

# %%
Income_2016B = pd.read_csv("2016Census_G17B_WA_POA.csv") #index_col = 0)

# %%
Income_2016C = pd.read_csv("2016Census_G17C_WA_POA.csv") #index_col = 0)

# %%
Income_2016_FirstMerge = pd.merge(Income_2016A, Income_2016B, left_on="POA_CODE_2016", right_on="POA_CODE_2016")

# %%
Income_2016 = pd.merge(Income_2016_FirstMerge, Income_2016C, left_on="POA_CODE_2016", right_on="POA_CODE_2016")

# %%
Income_2016.head()
# Out:
#   POA_CODE_2016  M_Neg_Nil_income_15_19_yrs  M_Neg_Nil_income_20_24_yrs  \
# 0       POA6000                          55                         111
# 1       POA6003                          11                          11
# 2       POA6004                          70                          80
# 3       POA6005                          28                          38
# 4       POA6006                          82                          23
#
#    M_Neg_Nil_income_25_34_yrs  M_Neg_Nil_income_35_44_yrs  \
# 0                         100                          41
# 1                          20                           8
# 2                          83                          35
# 3                          46                          16
# 4                          23                          20
#
#    M_Neg_Nil_income_45_54_yrs  M_Neg_Nil_income_55_64_yrs  \
# 0                          17                          20
# 1                           3                           6
# ...

# %%
Income_2016.columns.get_loc('P_Neg_Nil_income_Tot')
# Out:
# 330

# %%
Income_2016.columns.get_loc('P_3000_more_Tot')
# Out:
# 460

# %%
Income_2016_6010 = Income_2016.iloc[8, 330:461:10]
Income_2016_6010
# Out:
# P_Neg_Nil_income_Tot    1542
# P_1_149_Tot              720
# P_150_299_Tot            690
# P_300_399_Tot            648
# P_400_499_Tot            742
# P_500_649_Tot            708
# P_650_799_Tot            666
# P_800_999_Tot            769
# P_1000_1249_Tot          900
# P_1250_1499_Tot          736
# P_1500_1749_Tot          722
# P_1750_1999_Tot          583
# P_2000_2999_Tot         1204
# P_3000_more_Tot         1988
# Name: 8, dtype: object

# %%
plt.figure(figsize=(20, 10))
Income_2016_6010.plot(kind='bar', color = "green")

plt.xlabel("Personal Income Per Week")
plt.ylabel("Frequency")
plt.title("2016 Distribution of Personal Incomes Per Week in Claremont")
plt.show()

# %%
Income_2016_6015 = Income_2016.iloc[12, 330:461:10]
Income_2016_6015
# Out:
# P_Neg_Nil_income_Tot    600
# P_1_149_Tot             312
# P_150_299_Tot           260
# P_300_399_Tot           227
# P_400_499_Tot           245
# P_500_649_Tot           243
# P_650_799_Tot           251
# P_800_999_Tot           299
# P_1000_1249_Tot         343
# P_1250_1499_Tot         258
# P_1500_1749_Tot         252
# P_1750_1999_Tot         209
# P_2000_2999_Tot         460
# P_3000_more_Tot         979
# Name: 12, dtype: object

# %%
plt.figure(figsize=(20, 10))
Income_2016_6015.plot(kind='bar', color = "limegreen")

plt.xlabel("Personal Income Per Week")
plt.ylabel("Frequency")
plt.title("2016 Distribution of Personal Incomes Per Week in City Beach")
plt.show()

# %%
Income_2016_6056 = Income_2016.iloc[46, 330:461:10]
Income_2016_6056
# Out:
# P_Neg_Nil_income_Tot    3063
# P_1_149_Tot             1308
# P_150_299_Tot           2370
# P_300_399_Tot           2784
# P_400_499_Tot           2483
# P_500_649_Tot           2279
# P_650_799_Tot           2283
# P_800_999_Tot           2596
# P_1000_1249_Tot         2897
# P_1250_1499_Tot         1951
# P_1500_1749_Tot         1718
# P_1750_1999_Tot         1091
# P_2000_2999_Tot         1559
# P_3000_more_Tot          682
# Name: 46, dtype: object

# %%
plt.figure(figsize=(20, 10))
Income_2016_6056.plot(kind='bar', color = "lightgreen")

plt.xlabel("Personal Income Per Week")
plt.ylabel("Frequency")
plt.title("2016 Distribution of Personal Incomes Per Week in Midland")
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(1)
plt.figure(figsize=(10, 7))

plt.suptitle("Personal Income Per Week for People living in Claremont", fontsize = 15)


plt.subplot(121)
Income_2011_6010.plot(kind='bar', color = "green")
plt.xlabel("Personal Income/Week")
plt.ylabel("Number of Residents")
plt.title("2011", fontsize = 10)
plt.ylim(0, 2700)

plt.subplot(122)
Income_2016_6010.plot(kind='bar', color = "green") 
plt.xlabel("Personal Income/Week")
#plt.ylabel("Number of Residents")
plt.title("2016", fontsize = 10)
plt.ylim(0, 2700)

plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(1)
plt.figure(figsize=(10, 7))

plt.suptitle("Personal Income Per Week for People living in City Beach", fontsize = 15)


plt.subplot(121)
Income_2011_6015.plot(kind='bar', color = "limegreen")
plt.xlabel("Personal Income/Week")
plt.ylabel("Number of Residents")
plt.title("2011", fontsize = 10)
plt.ylim(0, 1300)

plt.subplot(122)
Income_2016_6015.plot(kind='bar', color = "limegreen") 
plt.xlabel("Personal Income/Week")
#plt.ylabel("Number of Residents")
plt.title("2016", fontsize = 10)
plt.ylim(0, 1300)

plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(1)
plt.figure(figsize=(10, 7))

plt.suptitle("Personal Income Per Week for People living in Midland", fontsize = 15)


plt.subplot(121)
Income_2011_6056.plot(kind='bar', color = "lightgreen")
plt.xlabel("Personal Income/Week")
plt.ylabel("Number of Residents")
plt.title("2011", fontsize = 10)
plt.ylim(0, 3100)

plt.subplot(122)
Income_2016_6056.plot(kind='bar', color = "lightgreen") 
plt.xlabel("Personal Income/Week")
#plt.ylabel("Number of Residents")
plt.title("2016", fontsize = 10)
plt.ylim(0, 3100)

plt.show()

# %% [markdown]
# If I want to try to attempt mapping, go to this website:
# http://www.datadependence.com/2016/06/creating-map-visualisations-in-python/
