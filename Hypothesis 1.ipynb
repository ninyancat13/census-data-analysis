# %% [markdown]
# # Census Data 2011
#
# ## Nina Kumagai

# %% [markdown]
# ## We will be testing three different hypotheses:
# ### 1. Larger proportion of older people live in the hills up north of Perth  compared to the inner city.
# ### 2. People living in the inner city suburbs are less likely to drive to work compared to those living in outer suburbs.
# ### 3. Rich people tend to live in areas where rent is more expensive.
#
#
# Each hypothesis will span three or more postcodes, and include/compare the  2011  and  2016 data.

# %% [markdown]
# TIPS:
#
# Dropping columns and rows:
# https://chrisalbon.com/python/data_wrangling/pandas_dropping_column_and_rows/
#
# Pandas textbook
# pandas: powerful Python data analysis toolkit
# Release 0.17.0
# Wes McKinney & PyData Development Team
# http://pandas.pydata.org/pandas-docs/version/0.17.0/pandas.pdf

# %% [markdown]
# Hypothesis 1
# More old people tend to live in the hills up north of Perth than in the inner city.

# %%
#2011 Data
import pandas as pd
Age_2011A = pd.read_csv("2011Census_B04A_WA_POA_short.csv") #index_col = 0)

# %%
Age_2011A.head()
# Out:
#   region_id  Age_yr_0_M  Age_yr_0_F  Age_yr_0_P  Age_yr_1_M  Age_yr_1_F  \
# 0   POA6000          34          47          81          37          43
# 1   POA6003          19          10          29           6          11
# 2   POA6004          32          37          69          44          24
# 3   POA6005          25          18          43          17          19
# 4   POA6006          64          63         127          61          54
#
#    Age_yr_1_P  Age_yr_2_M  Age_yr_2_F  Age_yr_2_P     ...       Age_yr_53_F  \
# 0          80          27          24          51     ...                42
# 1          17           3           9          12     ...                19
# 2          68          32          25          57     ...                51
# 3          36          14          14          28     ...                29
# 4         115          56          57         113     ...                54
#
#    Age_yr_53_P  Age_yr_54_M  Age_yr_54_F  Age_yr_54_P  Age_yr_50_54_M  \
# ...

# %%
Age_2011A.tail()
# Out:
#     region_id  Age_yr_0_M  Age_yr_0_F  Age_yr_0_P  Age_yr_1_M  Age_yr_1_F  \
# 329   POA6760           5           4           9           5           7
# 330   POA6762           5           3           8           3           4
# 331   POA6765          17           9          26          20          18
# 332   POA6770          34          19          53          45          26
# 333   POA6907           0           0           0           0           0
#
#      Age_yr_1_P  Age_yr_2_M  Age_yr_2_F  Age_yr_2_P     ...       Age_yr_53_F  \
# 329          12           0          10          10     ...                 3
# 330           7           3           0           3     ...                 0
# 331          38          15          14          29     ...                10
# 332          71          29          36          65     ...                19
# 333           0           0           0           0     ...                 3
#
# ...

# %%
#Age_2011A.dtypes

# %%
type(Age_2011A)
# Out:
# pandas.core.frame.DataFrame

# %%
#Age_2011A.columns.values

# %%
Age_2011B = pd.read_csv("2011Census_B04B_WA_POA_short.csv") 

#, index_col = 0

# %%
Age_2011 = pd.merge(Age_2011A, Age_2011B, left_on="region_id", right_on="region_id")

# %%
Age_2011.head()
# Out:
#   region_id  Age_yr_0_M  Age_yr_0_F  Age_yr_0_P  Age_yr_1_M  Age_yr_1_F  \
# 0   POA6000          34          47          81          37          43
# 1   POA6003          19          10          29           6          11
# 2   POA6004          32          37          69          44          24
# 3   POA6005          25          18          43          17          19
# 4   POA6006          64          63         127          61          54
#
#    Age_yr_1_P  Age_yr_2_M  Age_yr_2_F  Age_yr_2_P  ...    Age_yr_90_94_P  \
# 0          80          27          24          51  ...                13
# 1          17           3           9          12  ...                 6
# 2          68          32          25          57  ...                22
# 3          36          14          14          28  ...                28
# 4         115          56          57         113  ...                51
#
#    Age_yr_95_99_M  Age_yr_95_99_F  Age_yr_95_99_P  Age_yr_100_yr_over_M  \
# ...

# %%
Age_2011.tail()
# Out:
#     region_id  Age_yr_0_M  Age_yr_0_F  Age_yr_0_P  Age_yr_1_M  Age_yr_1_F  \
# 329   POA6760           5           4           9           5           7
# 330   POA6762           5           3           8           3           4
# 331   POA6765          17           9          26          20          18
# 332   POA6770          34          19          53          45          26
# 333   POA6907           0           0           0           0           0
#
#      Age_yr_1_P  Age_yr_2_M  Age_yr_2_F  Age_yr_2_P  ...    Age_yr_90_94_P  \
# 329          12           0          10          10  ...                 0
# 330           7           3           0           3  ...                 0
# 331          38          15          14          29  ...                 3
# 332          71          29          36          65  ...                 0
# 333           0           0           0           0  ...                 0
#
# ...

# %%
#Age_2011

# %%
#Age_2011.dtypes

# %%
#Age_2011.drop('', axis=1) To DROP a column, we tried to drop first column but it has no name. so instead use index.columns = 0

# %%
Age_2011.columns
# Out:
# Index(['region_id', 'Age_yr_0_M', 'Age_yr_0_F', 'Age_yr_0_P', 'Age_yr_1_M',
#        'Age_yr_1_F', 'Age_yr_1_P', 'Age_yr_2_M', 'Age_yr_2_F', 'Age_yr_2_P',
#        ...
#        'Age_yr_90_94_P', 'Age_yr_95_99_M', 'Age_yr_95_99_F', 'Age_yr_95_99_P',
#        'Age_yr_100_yr_over_M', 'Age_yr_100_yr_over_F', 'Age_yr_100_yr_over_P',
#        'Tot_M', 'Tot_F', 'Tot_P'],
#       dtype='object', length=307)

# %%
Age_2011.columns.get_loc('Age_yr_75_79_P')
# Out:
# 288

# %%
Age_2011_6000 = Age_2011.iloc[0, 18:289:18]
#[['POA6000'], :]

# Please note that the POA6000 row index was identified by running ctrl f on excel, to find POA6000.
# Whatever the row number on excel - 2, gives us the row index for the table Age_2011_6000.

# %%
Age_2011_6070 = Age_2011.iloc[60, 18:289:18]

# %%
Age_2011_6107 = Age_2011.iloc[81, 18:289:18]

# %%
Age_2011_6000
# Out:
# Age_yr_0_4_P       307
# Age_yr_5_9_P       142
# Age_yr_10_14_P     124
# Age_yr_15_19_P     269
# Age_yr_20_24_P    1188
# Age_yr_25_29_P    1937
# Age_yr_30_34_P    1430
# Age_yr_35_39_P     792
# Age_yr_40_44_P     613
# Age_yr_45_49_P     501
# Age_yr_50_54_P     503
# Age_yr_55_59_P     466
# Age_yr_60_64_P     342
# Age_yr_65_69_P     225
# Age_yr_70_74_P     139
# Age_yr_75_79_P     101
# Name: 0, dtype: object

# %%
Age_2011_6070
# Out:
# Age_yr_0_4_P      35
# Age_yr_5_9_P      39
# Age_yr_10_14_P    59
# Age_yr_15_19_P    75
# Age_yr_20_24_P    54
# Age_yr_25_29_P    36
# Age_yr_30_34_P    32
# Age_yr_35_39_P    34
# Age_yr_40_44_P    56
# Age_yr_45_49_P    81
# Age_yr_50_54_P    83
# Age_yr_55_59_P    68
# Age_yr_60_64_P    60
# Age_yr_65_69_P    47
# Age_yr_70_74_P    27
# Age_yr_75_79_P    23
# Name: 60, dtype: object

# %%
Age_2011_6107
# Out:
# Age_yr_0_4_P      795
# Age_yr_5_9_P      608
# Age_yr_10_14_P    654
# Age_yr_15_19_P    720
# Age_yr_20_24_P    745
# Age_yr_25_29_P    938
# Age_yr_30_34_P    815
# Age_yr_35_39_P    709
# Age_yr_40_44_P    671
# Age_yr_45_49_P    654
# Age_yr_50_54_P    667
# Age_yr_55_59_P    627
# Age_yr_60_64_P    629
# Age_yr_65_69_P    422
# Age_yr_70_74_P    335
# Age_yr_75_79_P    267
# Name: 81, dtype: object

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(20, 10))
Age_2011_6000.plot(kind='bar')

plt.xlabel("Age")
plt.ylabel("Number of Residents")
plt.title("2011 Age Distribution of People living in Perth City")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(20, 10))
Age_2011_6070_plot = Age_2011_6070.plot(kind='bar', color='purple')

plt.xlabel("Age")
plt.ylabel("Number of Residents")
plt.title("2011 Age Distribution of People living in Darlington")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(20, 10))
Age_2011_6107.plot(kind='bar', color='violet')

plt.xlabel("Age")
plt.ylabel("Number of Residents")
plt.title("2011 Age Distribution of People living in Cannington")
plt.show()

# %% [markdown]
# Now that we have the 2011 comparison, let us compare this output with the 2016 outcome!

# %%
Age_2016A = pd.read_csv("2016Census_G04A_WA_POA.csv")

# %%
Age_2016B = pd.read_csv("2016Census_G04B_WA_POA.csv")

# %%
Age_2016 = pd.merge(Age_2016A, Age_2016B, left_on="POA_CODE_2016", right_on="POA_CODE_2016")

# %%
Age_2016.head()
# Out:
#   POA_CODE_2016  Age_yr_0_M  Age_yr_0_F  Age_yr_0_P  Age_yr_1_M  Age_yr_1_F  \
# 0       POA6000          61          63         121          52          45
# 1       POA6003          14          17          32           4          15
# 2       POA6004          59          57         108          36          48
# 3       POA6005          19          29          47          29          28
# 4       POA6006          54          45          94          47          53
#
#    Age_yr_1_P  Age_yr_2_M  Age_yr_2_F  Age_yr_2_P  ...    Age_yr_90_94_P  \
# 0          95          40          40          78  ...                28
# 1          22           7           7          12  ...                 5
# 2          86          39          40          76  ...                20
# 3          54          16           7          27  ...                30
# 4          95          47          42          92  ...                74
#
# ...

# %%
Age_2016.columns.get_loc('Age_yr_75_79_P')
# Out:
# 288

# %%
Age_2016_6000 = Age_2016.iloc[0, 18:289:18]
Age_2016_6000
# Out:
# Age_yr_0_4_P       449
# Age_yr_5_9_P       199
# Age_yr_10_14_P     148
# Age_yr_15_19_P     298
# Age_yr_20_24_P    1315
# Age_yr_25_29_P    2300
# Age_yr_30_34_P    2074
# Age_yr_35_39_P    1153
# Age_yr_40_44_P     707
# Age_yr_45_49_P     581
# Age_yr_50_54_P     504
# Age_yr_55_59_P     444
# Age_yr_60_64_P     450
# Age_yr_65_69_P     321
# Age_yr_70_74_P     176
# Age_yr_75_79_P     127
# Name: 0, dtype: object

# %%
Age_2016_6070 = Age_2016.iloc[60, 18:289:18]
Age_2016_6070
# Out:
# Age_yr_0_4_P      207
# Age_yr_5_9_P      294
# Age_yr_10_14_P    275
# Age_yr_15_19_P    263
# Age_yr_20_24_P    137
# Age_yr_25_29_P     96
# Age_yr_30_34_P    141
# Age_yr_35_39_P    203
# Age_yr_40_44_P    263
# Age_yr_45_49_P    330
# Age_yr_50_54_P    283
# Age_yr_55_59_P    258
# Age_yr_60_64_P    256
# Age_yr_65_69_P    257
# Age_yr_70_74_P    193
# Age_yr_75_79_P    106
# Name: 60, dtype: object

# %%
Age_2016_6107 = Age_2016.iloc[81, 18:289:18]
Age_2016_6107
# Out:
# Age_yr_0_4_P      3416
# Age_yr_5_9_P      2755
# Age_yr_10_14_P    2155
# Age_yr_15_19_P    2351
# Age_yr_20_24_P    4050
# Age_yr_25_29_P    4884
# Age_yr_30_34_P    4967
# Age_yr_35_39_P    3606
# Age_yr_40_44_P    2823
# Age_yr_45_49_P    2407
# Age_yr_50_54_P    2181
# Age_yr_55_59_P    1968
# Age_yr_60_64_P    1651
# Age_yr_65_69_P    1512
# Age_yr_70_74_P    1000
# Age_yr_75_79_P     794
# Name: 81, dtype: object

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(20, 10))
Age_2016_6000.plot(kind='bar')

plt.xlabel("Age")
plt.ylabel("Number of Residents")
plt.title("2016 Age Distribution of People living in Perth City")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(20, 10))
Age_2016_6070.plot(kind='bar', color='purple')

plt.xlabel("Age")
plt.ylabel("Number of Residents")
plt.title("2016 Age Distribution of People living in Darlington")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(20, 10))
Age_2016_6107.plot(kind='bar', color='violet')

plt.xlabel("Age")
plt.ylabel("Number of Residents")
plt.title("2016 Age Distribution of People living in Cannington")
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(1)
plt.figure(figsize=(10, 7))

plt.suptitle("Age Distribution of People Living in Perth City", fontsize = 15)


plt.subplot(121)
Age_2011_6000.plot(kind='bar')
plt.xlabel("Age")
plt.ylabel("Number of Residents")
plt.title("2011", fontsize = 10)
plt.ylim(0, 2500)

plt.subplot(122)
Age_2016_6000.plot(kind='bar') 
plt.xlabel("Age")
plt.ylabel("Number of Residents")
plt.title("2016", fontsize = 10)
plt.ylim(0, 2500)

plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(1)
plt.figure(figsize=(10, 7))

plt.suptitle("Age Distribution of People Living in Darlington", fontsize = 15)


plt.subplot(121)
Age_2011_6070.plot(kind='bar', color = "purple")
plt.xlabel("Age")
plt.ylabel("Number of Residents")
plt.title("2011", fontsize = 10)
plt.ylim(0, 350)

plt.subplot(122)
Age_2016_6070.plot(kind='bar', color = "purple") 
plt.xlabel("Age")
plt.ylabel("Number of Residents")
plt.title("2016", fontsize = 10)
plt.ylim(0, 350)

plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(1)
plt.figure(figsize=(10, 7))

plt.suptitle("Age Distribution of People Living in Cannington", fontsize = 15)


plt.subplot(121)
Age_2011_6107.plot(kind='bar', color = "violet")
plt.xlabel("Age")
plt.ylabel("Number of Residents")
plt.title("2011", fontsize = 10)
plt.ylim(0, 5000)

plt.subplot(122)
Age_2016_6107.plot(kind='bar', color = "violet") 
plt.xlabel("Age")
#plt.ylabel("Number of Residents")
plt.title("2016", fontsize = 10)
plt.ylim(0, 5000)

plt.show()
